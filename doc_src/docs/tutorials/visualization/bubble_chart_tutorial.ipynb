# %% [markdown]
# # BubbleChart Visualization Tutorial
#
# This tutorial shows how to use the `BubbleChart` class from the Lexos visualization module to create packed bubble plots.
#
# It supports a variety of input types including plain text, token lists, spaCy docs, dataframes, and document-term matrices (DTM).
#
# We’ll walk through simple examples, from setup to customization and saving.
